# %%
import pandas as pd

# %%
data = [["DATETIME","Date and time of the historic generation mix and carbon intensity"],
     ["GAS","Amount of generation delivered by this fuel type"],
     ["COAL","Amount of generation delivered by this fuel type"],
     ["NUCLEAR","Amount of generation delivered by this fuel type"], 
     ["WIND","Amount of generation delivered by this fuel type"],
     ["HYDRO","Amount of generation delivered by this fuel type"],
     ["IMPORTS","Interconnector Imports"], 
     ["BIOMASS","Amount of generation delivered by this fuel type"],
     ["OTHER","Amount of generation delivered by other fuel types"],
     ["SOLAR","Amount of generation delivered by this fuel type"], 
     ["STORAGE","Amount of generation delivered by this fuel type"],
     ["GENERATION","Sum of gas, coal, nuclear, wind, hydro and imports"],
     ["CARBON_INTENSITY","The carbon intensity of electricity is a measure of how much Carbon dioxide emissions are produced per kilowatt hour of electricity consumed."], 
     ["LOW_CARBON","Low carbon generation e.g. wind, solar, hydro, nuclear, biomass"],
     ["ZERO_CARBON","Zero carbon generation e.g. wind, solar, hydro, nuclear"],
     ["RENEWABLE","Renewable generation e.g Wind, Hydro, Solar"], 
     ["FOSSIL","Fossil generation e.g. coal, natural gas"],
     ["GAS_perc","Fuel Type as a percentage for gas generation"],
     ["COAL_perc","Fuel Type as a percentage for coal generation"], 
     ["NUCLEAR_perc","Fuel Type as a percentage for nuclear generation"],
     ["WIND_perc","Fuel Type as a percentage for wind generation"],
     ["HYDRO_perc","Fuel Type as a percentage for hydro generation"],
     ["IMPORTS_perc","Fuel Type as a percentage for interconnector imports"], 
     ["BIOMASS_perc","Fuel Type as a percentage for biomass generation"],
     ["OTHER_perc","Fuel Type as a percentage for other generation"],
     ["SOLAR_perc","Fuel Type as a percentage for solar generation"], 
     ["STORAGE_perc","Fuel Type as a percentage for storage"],
     ["GENERATION_perc","Fuel Type as a percentage for Sum of gas, coal, nuclear, wind, hydro and imports"], 
     ["LOW_CARBON_perc","Fuel Type as a percentage for low carbon generation e.g. wind, solar, hydro, nuclear, biomass"],
     ["ZERO_CARBON_perc","Fuel Type as a percentage for zero carbon generation e.g. wind, solar, hydro, nuclear"], 
     ["RENEWABLE_perc","Fuel Type as a percentage for Renewable generation e.g Wind, Hydro, Solar"],
     ["FOSSIL_perc","Fuel Type as a percentage for Fossil generation e.g. coal, natural gas"],
     ]


glossary = pd.DataFrame(data)
glossary.columns = ['Column', 'Description']
glossary.style.set_table_styles({
    'Description': [{'selector': '',
           'props': [('width', '1000px')]}],
}, overwrite=False)
glossary
# Out:
#               Column  \
# 0           DATETIME
# 1                GAS
# 2               COAL
# 3            NUCLEAR
# 4               WIND
# 5              HYDRO
# 6            IMPORTS
# 7            BIOMASS
# 8              OTHER
# 9              SOLAR
# 10           STORAGE
# 11        GENERATION
# 12  CARBON_INTENSITY
# 13        LOW_CARBON
# 14       ZERO_CARBON
# 15         RENEWABLE
# 16            FOSSIL
# 17          GAS_perc
# 18         COAL_perc
# 19      NUCLEAR_perc
# 20         WIND_perc
# 21        HYDRO_perc
# 22      IMPORTS_perc
# 23      BIOMASS_perc
# 24        OTHER_perc
# 25        SOLAR_perc
# 26      STORAGE_perc
# 27   GENERATION_perc
# 28   LOW_CARBON_perc
# 29  ZERO_CARBON_perc
# 30    RENEWABLE_perc
# 31       FOSSIL_perc
#
#                                                                                                                                       Description
# ...

# %% [markdown]
# Historic GB generation mix from the 1st of Jan 2009 through to Feb 2024. Data points are either MW or %.
